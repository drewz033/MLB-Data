# %%
from pybaseball import statcast
from pybaseball.lahman import *
from pybaseball import playerid_lookup

# %%
download_lahman()

# %%
people=people()

# %%
people.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID'],
#       dtype='object')

# %%
batting=batting()

# %%
hou = batting.loc[(batting['teamID']=='HOU')&(batting['yearID']==2017)]

# %%
data = statcast('2017-04-04','2017-09-30')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2017-04-04 to 2017-04-09
# Completed sub-query from 2017-04-10 to 2017-04-15
# Completed sub-query from 2017-04-16 to 2017-04-21
# Completed sub-query from 2017-04-22 to 2017-04-27
# Completed sub-query from 2017-04-28 to 2017-05-03
# Completed sub-query from 2017-05-04 to 2017-05-09
# Completed sub-query from 2017-05-10 to 2017-05-15
# Completed sub-query from 2017-05-16 to 2017-05-21
# Completed sub-query from 2017-05-22 to 2017-05-27
# Completed sub-query from 2017-05-28 to 2017-06-02
# C:\Users\Drew\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# Completed sub-query from 2017-06-03 to 2017-06-08
# Completed sub-query from 2017-06-09 to 2017-06-14
# Completed sub-query from 2017-06-15 to 2017-06-20
# ...

# %%
altuve = data[data['batter']==514888]

# %%
playerid_lookup('altuve','jose')
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0    altuve       jose     501447       NaN        NaN             -1
# 1    altuve       jose     514888  altuj001  altuvjo01           5417
#
#    mlb_played_first  mlb_played_last
# 0               NaN              NaN
# 1            2011.0           2019.0

# %%
altuve_offspeed = altuve[altuve['pitch_type'].isin(['CU','KC','CH','FO','KN','SL','SI'])]

# %%
altuve_offspeed = altuve_offspeed.dropna(subset=['events'])

# %%
altuve_offspeed.groupby(['pitch_type','events']).count()
# Out:
#                                       index  game_date  release_speed  \
# pitch_type events
# CH         double                         1          1              1
#            field_out                     32         32             32
#            force_out                      2          2              2
#            grounded_into_double_play      1          1              1
#            home_run                       6          6              6
#            single                         9          9              9
#            strikeout                      6          6              6
#            triple                         1          1              1
#            walk                           8          8              8
# CU         caught_stealing_2b             1          1              1
#            double                         3          3              3
#            field_out                     18         18             18
# ...

# %%
# Out:
# index                              39
# pitch_type                         39
# game_date                          39
# release_speed                      39
# release_pos_x                      39
# release_pos_z                      39
# player_name                        39
# batter                             39
# pitcher                            39
# events                             39
# description                        39
# spin_dir                            0
# spin_rate_deprecated                0
# break_angle_deprecated              0
# break_length_deprecated             0
# zone                               39
# des                                39
# game_type                          39
# stand                              39
# p_throws                           39
# home_team                          39
# away_team                          39
# type                               39
# hit_location                       36
# bb_type                            39
# ...
